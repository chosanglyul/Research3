# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../rawdata/sunspots.csv', index_col='Unnamed: 0')
df.columns = ['Date', 'Sunspot']
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')
df
# Out:
#             Sunspot
# Date
# 1749-01-31     96.7
# 1749-02-28    104.3
# 1749-03-31    116.7
# 1749-04-30     92.8
# 1749-05-31    141.7
# ...             ...
# 2019-08-31      0.5
# 2019-09-30      1.1
# 2019-10-31      0.4
# 2019-11-30      0.5
# 2019-12-31      1.6
#
# [3252 rows x 1 columns]

# %%
for i in range(1, 265):
    df['Sunspot_{}'.format(i)] = df['Sunspot'].shift(i)
df.dropna(inplace=True)
df = df.loc[:, ::-1]
df
# Out:
#             Sunspot_264  Sunspot_263  Sunspot_262  Sunspot_261  Sunspot_260  \
# Date
# 1771-01-31         96.7        104.3        116.7         92.8        141.7
# 1771-02-28        104.3        116.7         92.8        141.7        139.2
# 1771-03-31        116.7         92.8        141.7        139.2        158.0
# 1771-04-30         92.8        141.7        139.2        158.0        110.5
# 1771-05-31        141.7        139.2        158.0        110.5        126.5
# ...                 ...          ...          ...          ...          ...
# 2019-08-31         35.7         59.7         32.8         50.4         55.5
# 2019-09-30         59.7         32.8         50.4         55.5         44.5
# 2019-10-31         32.8         50.4         55.5         44.5         50.2
# 2019-11-30         50.4         55.5         44.5         50.2         82.0
# 2019-12-31         55.5         44.5         50.2         82.0         70.6
#
# ...

# %%
plt.plot(df['Sunspot'])

# %%
a = ['Sunspot_{}'.format(i) for i in range(1, 265)]
a.append('Sunspot')
plt.plot(range(1, 266), df[a].corr()['Sunspot'])

# %%
df.to_csv('../preprocess/sunspots.csv')
